# %%
import numpy as np
import pandas as pd

# %%
data=[(3,2,60),
      (4,0,130),
      (5,6,170),
      (2,10,40)
]
df=pd.DataFrame(data,columns=["No. of rooms","No. of grocery shop","Price"])

# %%
df
# Out:
#    No. of rooms  No. of grocery shop  Price
# 0             3                    2     60
# 1             4                    0    130
# 2             5                    6    170
# 3             2                   10     40
