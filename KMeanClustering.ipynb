# %%
import numpy as np
import pandas as pd

# %%
data=[[5.13,88],
     [5.90,113],
     [8.36,93],
      [8.27,97],
      [95.45,110]
     ]
df=pd.DataFrame(data,columns=['cgpa','iq'])

# %%
df
# Out:
#     cgpa   iq
# 0   5.13   88
# 1   5.90  113
# 2   8.36   93
# 3   8.27   97
# 4  95.45  110

# %%
import matplotlib.pyplot as plt
plt.scatter(df['cgpa'],df['iq'])
